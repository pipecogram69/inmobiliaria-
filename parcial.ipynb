# %% [markdown]
# <a href="https://colab.research.google.com/github/pipecogram69/inmobiliaria-/blob/main/parcial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Elaborado por Julian Felipe Cortes-Andres Felipe Ortegon
#1.- Deberá emplear las herramientas de Diseño, Bases de Datos y Desarrollo que
#están trabajando en sus actividades como estudiante en el programa de
#Ingeniería de Sistemas.
#2.- Este trabajo deberá establecer y listar las Calificaciones de treinta (30)
#Estudiantes de una Asignatura, Teniendo en cuenta que hay cuatro notas
#Investigación, Taller, Quiz y Parcial. Se debe registrar por cada Estudiante El
#Código (Identificación), Nombre, Notas Parciales y Nota definitiva.
#3.- Se deben registrar y listar las Cuatro Calificaciones por cada Estudiante,
#Investigación, Taller, Quiz y Parcial, generando un promedio por estudiante y
#establecer, una clasificación de la nota definitiva de mayor a menor, (de la
#nota promedio) con el Código, Nombre, Notas y Nota promedio.
#4.- Se debe listar el número Total de Estudiantes con la Calificación definitiva, con
#el Código, Nombre y Notas, y generar la nota promedio del curso.
#5.- Se debe listar los diez (10) primeros Estudiantes con la Calificación más alta
#clasificada de mayor a menor con el Código, Nombre y la Calificación definitiva.
#6.- Se debe listar los cinco (5) últimos Estudiantes con la Nota más baja clasificada
#de menor a mayor con el Código, Nombre y la Calificación definitiva.
#7.- Se debe generar y listar el total de estudiantes que aprobaron y los que no
#aprobaron la asignatura con el Código, Nombre y la Calificación definitiva.
#8.- Se debe generar Estadísticas y porcentajes por cada requerimiento establecido
#9.- Se debe generar Graficas con los porcentajes de cada requerimiento y
#distinguidas con diferentes estilos y colores con el fin de visualizar lo
#solicitado.

#Condiciones y Requerimientos del trabajo a realizar.

# %%
#importacion de el guardado de documento
from google.colab import files
from google.colab import drive

drive .mount('/content/drive')

# %%
#importacion de librerias
import pandas as pd
import numpy as np
import xlrd
import seaborn as sb
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter

# %%
#importacion del documento en numero de fila y columnas
import pandas as pd
df=pd.read_excel("/content/lista_de_estudiantes.xlsx")
df.shape
# Out:
# (30, 8)

# %%
#tipo de datos
df.dtypes
print ('\nLos datos son de tipo: \n',df.dtypes)
# Out:
# Los datos son de tipo:
#  NOMBRE                object
# CODIGO                 int64
# INVESTIGACION        float64
# TALLER               float64
# QUIZ                 float64
# PARCIAL              float64
# NOTAS PARCIALES      float64
# dtype: object

# %%
#impresion de los 30 datos
df.head(30)
# Out:
#                                       NOMBRE  CODIGO  INVESTIGACION   TALLER  \
# 0   FELIPE ORTEGON                              1010             4.1     4.0
# 1                   CAMILA FERNANDEZ            1011             3.5     3.0
# 2                             JHONATAN ORTIZ    1012             5.0     4.0
# 3                           MANUELA MOSQUERA    1013             4.2     5.0
# 4                            LAURA CARDENAS     1014             3.7     5.0
# 5                             DAVID MORALES     1015             4.0     5.0
# 6                              FELIPE CORTES    1016             4.6     0.0
# 7                            MARIA GUTIERREZ    1017             4.5     1.5
# 8                             VALENTNA ORTIZ    1018             3.9     4.4
# 9                            PEDRO RODRIGUEZ    1019             4.5     5.0
# 10                            MARIA CARREÑO     1020             3.0     5.0
# 11                               LINA CORTES    1021             2.0     3.8
# 12                        VALENTNA GUTIERREZ    1022             2.9     3.5
# 13                           CAMILO SANDOVAL    1023             5.0     5.0
# 14                            SAMUEL MORENO     1024             4.3     4.0
# 15                          TATIANA MARTINEZ    1025             4.8     4.0
# 16                            ESTIVEN PEREZ     1026             0.0     0.0
# 17                           CAMILA SANCHEZ     1027             4.2     0.0
# 18                           NICOLAS GARCIA     1028             4.4     5.0
# 19                           LUNA HERNANDEZ     1029             4.5     3.5
# 20                         JUAN PABLO GOMEZ     1030             2.0     4.0
# 21                      MARIA JOSE GONZALES     1031             4.0     2.5
# 22                                JHON DIAZ     1032             3.2     4.4
# 23                            DARWIN VARGAS     1033             3.5     5.0
# 24                         ALEJANDRA TORRES     1034             4.0     5.0
# 25                           LUISA CASTILLO     1035             4.5     4.0
# 26  ANGELICA ZAPATA                             1036             4.6     3.2
# 27                           CRISTIAN PARRA     1037             1.9     3.8
# 28                               JENNY RIOS     1038             4.9     0.0
# 29                             DIEGO OSPINA     1039             3.8     4.0
#
#     QUIZ  PARCIAL   NOTAS PARCIALES   NOTAS DEFINITIVAS
# 0    2.9       3.1                3.5          Aprobado
# 1    3.5       2.0                3.0         Reprobado
# 2    1.0       2.8                3.2         Reprobado
# 3    4.5       4.1                4.5          Aprobado
# 4    3.9       4.0                4.2          Aprobado
# 5    3.6       3.8                4.1          Aprobado
# 6    2.0       5.0                2.9         Reprobado
# 7    5.0       3.9                3.7          Aprobado
# 8    5.0       2.3                3.9          Aprobado
# 9    4.1       3.2                4.2          Aprobado
# 10   4.0       4.0                4.0          Aprobado
# 11   0.0       1.5                1.8         Reprobado
# 12   5.0       3.9                3.8          Aprobado
# 13   4.0       3.5                4.4          Aprobado
# 14   3.6       5.0                4.2          Aprobado
# 15   3.2       5.0                4.3          Aprobado
# 16   1.9       2.5                1.1         Reprobado
# 17   4.0       2.9                2.8         Reprobado
# 18   5.0       2.0                4.1          Aprobado
# 19   5.0       5.0                4.5          Aprobado
# 20   0.0       1.0                1.8         Reprobado
# 21   2.5       5.0                3.5         Reprobado
# 22   5.0       4.0                4.2          Aprobado
# 23   4.9       4.0                4.4          Aprobado
# 24   2.0       2.0                3.3         Reprobado
# 25   5.0       5.0                4.6          Aprobado
# 26   3.0       4.2                3.8          Aprobado
# 27   1.0       1.9                2.2         Reprobado
# 28   2.0       2.5                2.4         Reprobado
# 29   3.8       4.0                3.9          Aprobado

# %%
#nombre alumnos
print (df['NOMBRE'])
# Out:
# 0     FELIPE ORTEGON
# 1                     CAMILA FERNANDEZ
# 2                               JHONATAN ORTIZ
# 3                             MANUELA MOSQUERA
# 4                              LAURA CARDENAS
# 5                               DAVID MORALES
# 6                                FELIPE CORTES
# 7                              MARIA GUTIERREZ
# 8                               VALENTNA ORTIZ
# 9                              PEDRO RODRIGUEZ
# 10                              MARIA CARREÑO
# 11                                 LINA CORTES
# 12                          VALENTNA GUTIERREZ
# 13                             CAMILO SANDOVAL
# 14                              SAMUEL MORENO
# 15                            TATIANA MARTINEZ
# 16                              ESTIVEN PEREZ
# 17                             CAMILA SANCHEZ
# 18                             NICOLAS GARCIA
# 19                             LUNA HERNANDEZ
# 20                           JUAN PABLO GOMEZ
# 21                        MARIA JOSE GONZALES
# 22                                  JHON DIAZ
# 23                              DARWIN VARGAS
# 24                           ALEJANDRA TORRES
# 25                             LUISA CASTILLO
# 26    ANGELICA ZAPATA
# 27                             CRISTIAN PARRA
# 28                                 JENNY RIOS
# 29                               DIEGO OSPINA
# Name: NOMBRE, dtype: object

# %%
print (df['CODIGO'])
# Out:
# 0     1010
# 1     1011
# 2     1012
# 3     1013
# 4     1014
# 5     1015
# 6     1016
# 7     1017
# 8     1018
# 9     1019
# 10    1020
# 11    1021
# 12    1022
# 13    1023
# 14    1024
# 15    1025
# 16    1026
# 17    1027
# 18    1028
# 19    1029
# 20    1030
# 21    1031
# 22    1032
# 23    1033
# 24    1034
# 25    1035
# 26    1036
# 27    1037
# 28    1038
# 29    1039
# Name: CODIGO, dtype: int64

# %%
df['PARCIAL '].value_counts()
# Out:
# 5.0    6
# 4.0    5
# 2.0    3
# 3.9    2
# 2.5    2
# 3.1    1
# 3.5    1
# 4.2    1
# 1.0    1
# 2.9    1
# 2.3    1
# 1.5    1
# 3.2    1
# 3.8    1
# 4.1    1
# 2.8    1
# 1.9    1
# Name: PARCIAL , dtype: int64

# %%
from enum import auto
conteo_variable=df['NOTAS DEFINITIVAS'].value_counts()
etiquetas=df['NOTAS DEFINITIVAS'].unique()
colores="#60CE96","#E75353"
extraccion=0,0.2
plt.pie(conteo_variable,labels=etiquetas,autopct="%0.1f %%",colors=colores,explode=extraccion)
plt.show()

# %%
df['NOTAS DEFINITIVAS'].unique()
# Out:
# array(['Aprobado', 'Reprobado'], dtype=object)

# %%
df=pd.DataFrame(df)
promedio=df['NOTAS PARCIALES  '].mean()
print(f'el promedio de las notas es: {promedio}')
# Out:
# el promedio de las notas es: 3.543333333333334

# %%
df=pd.DataFrame(df)
df_sorted = df.sort_values(by='NOTAS PARCIALES  ', ascending=False).head(10)
print(df_sorted)
# Out:
#               NOMBRE  CODIGO  INVESTIGACION   TALLER  QUIZ  PARCIAL   \
# 25   LUISA CASTILLO     1035             4.5     4.0   5.0       5.0
# 3   MANUELA MOSQUERA    1013             4.2     5.0   4.5       4.1
# 19   LUNA HERNANDEZ     1029             4.5     3.5   5.0       5.0
# 13   CAMILO SANDOVAL    1023             5.0     5.0   4.0       3.5
# 23    DARWIN VARGAS     1033             3.5     5.0   4.9       4.0
# 15  TATIANA MARTINEZ    1025             4.8     4.0   3.2       5.0
# 22        JHON DIAZ     1032             3.2     4.4   5.0       4.0
# 4    LAURA CARDENAS     1014             3.7     5.0   3.9       4.0
# 9    PEDRO RODRIGUEZ    1019             4.5     5.0   4.1       3.2
# 14    SAMUEL MORENO     1024             4.3     4.0   3.6       5.0
#
#     NOTAS PARCIALES   NOTAS DEFINITIVAS  DESVIACION E  promedio
# 25                4.6          Aprobado           4.6       4.6
# 3                 4.5          Aprobado           4.5       4.5
# 19                4.5          Aprobado           4.5       4.5
# 13                4.4          Aprobado           4.4       4.4
# 23                4.4          Aprobado           4.4       4.4
# 15                4.3          Aprobado           4.3       4.3
# 22                4.2          Aprobado           4.2       4.2
# 4                 4.2          Aprobado           4.2       4.2
# 9                 4.2          Aprobado           4.2       4.2
# 14                4.2          Aprobado           4.2       4.2

# %%
df=pd.DataFrame(df)
df_sorted = df.sort_values(by='NOTAS PARCIALES  ', ascending=False).tail(5)
print(df_sorted)
# Out:
#                NOMBRE  CODIGO  INVESTIGACION   TALLER  QUIZ  PARCIAL   \
# 28        JENNY RIOS     1038             4.9     0.0   2.0       2.5
# 27    CRISTIAN PARRA     1037             1.9     3.8   1.0       1.9
# 11        LINA CORTES    1021             2.0     3.8   0.0       1.5
# 20  JUAN PABLO GOMEZ     1030             2.0     4.0   0.0       1.0
# 16     ESTIVEN PEREZ     1026             0.0     0.0   1.9       2.5
#
#     NOTAS PARCIALES   NOTAS DEFINITIVAS  DESVIACION E  promedio
# 28                2.4         Reprobado           2.4       2.4
# 27                2.2         Reprobado           2.2       2.2
# 11                1.8         Reprobado           1.8       1.8
# 20                1.8         Reprobado           1.8       1.8
# 16                1.1         Reprobado           1.1       1.1

# %%
df=pd.DataFrame(df)
total_estudiantes=len(df)
promedio_curso=df['NOTAS PARCIALES  '].mean()

print(f'NUMERO TOTAL DE ESTUDIANTES:{total_estudiantes}')
print(f'nota promedio del curso: {promedio_curso: .2f}')
# Out:
# NUMERO TOTAL DE ESTUDIANTES:30
# nota promedio del curso:  3.54
